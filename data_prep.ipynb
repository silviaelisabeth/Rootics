# %%
# %run functions_dbs.py

# %% [markdown]
# user input

# %%
# given by the user
file = 'dataPrep/Burggraben 2021 Oktober O2 and pH.xls'

# define storage path by user
inputSaveLineEdit = '20220125_Results/'

# %%
ddata = _loadFile4GUI(file=file, savePath=inputSaveLineEdit)
